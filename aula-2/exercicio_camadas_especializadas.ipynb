# %% [markdown]
# <div style="text-align: left;">
#
# ## Módulo: Analytics Engineering
#
# <br>
#
# ## Aula 1 - Exercício 1

# %% [markdown]
# #### Desenvolver um pipeline de dados para a análise de sentimento de notícias relacionadas ao Bitcoin usando dados obtidos da API Alpha Vantage (https://www.alphavantage.co/documentation/) com os seguintes passos:
#
# > #### 1: Fazer uma chamada à API Alpha Vantage com a função NEWS_SENTIMENT para obter dados de sentimento de notícias relacionadas ao Bitcoin. Exemplo a seguir:
# > #### 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=CRYPTO:BTC&time_from=20230926T0000&limit=1000&apikey=' + api_key'
#
# #### 'function=NEWS_SENTIMENT':  Este é o parâmetro que especifica a função da API que está sendo chamada, neste caso, a função "NEWS_SENTIMENT" que retorna informações de sentimento de notícias.
#
# #### 'tickers=CRYPTO:BTC': Neste parâmetro, é especificado o ticker do ativo financeiro que deseja ser analisado. No caso em questão, é "CRYPTO:BTC", indicando que análises de sentimento de notícias relacionadas ao Bitcoin estão sendo solicitadas.
#
# #### 'time_from=20230926T0000': Este parâmetro define a data e hora a partir das quais as informações de sentimento de notícias são solicitadas. No exemplo fornecido, a data é definida como 26 de setembro de 2023 às 00:00 (meia-noite).
#
# #### 'limit=1000': Este parâmetro define o número máximo de notícias a serem recuperadas. No exemplo mencionado, a busca está limitada a 1000 notícias.
#
# #### 'apikey=': Aqui é preciso adicionar a chave da API adquirida via login no site da API.
#
# #### O resultado dessa chamada à API será um conjunto de informações de sentimento de notícias relacionadas ao Bitcoin, incluindo possíveis métricas de sentimento, pontuações, resumos ou outros dados relevantes. O formato e a estrutura exatos dos dados dependem da API Alpha Vantage e das informações disponíveis em seu serviço no momento da chamada.

# %%
import requests

url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=CRYPTO:BTC&time_from=20240412T0000&limit=1000&apikey=API_KEY'
r = requests.get(url)

data = r.json()

print(data)
# Out:
# {'items': '141', 'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish', 'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.', 'feed': [{'title': 'KuCoin Announces a Monumental $20 Million Gratitude Airdrop for Its Loyal Community', 'url': 'https://www.prnewswire.com/apac/news-releases/kucoin-announces-a-monumental-20-million-gratitude-airdrop-for-its-loyal-community-302116186.html', 'time_published': '20240415T021900', 'authors': ['KuCoin'], 'summary': 'VICTORIA, Seychelles, April 15, 2024 /PRNewswire/ -- KuCoin, a global leader in the cryptocurrency exchange market, has fulfilled its honor and has successfully completed the distribution of an $8.95 million airdrop to users affected by withdrawal congestion.', 'banner_image': 'https://mma.prnewswire.com/media/2356857/KuCoin_Horizontal_Green_LOGO_Logo.jpg?p=facebook', 'source': 'PR Newswire', 'category_within_source': 'n/a', 'source_domain': 'www.prnewswire.com', 'topics': [{'topic': 'Blockchain', 'relevance_score': '0.838487'}, {'topic': 'Financial Markets', 'relevance_score': '0.266143'}], 'overall_sentiment_score': 0.461722, 'overall_sentiment_label': 'Bullish', 'ticker_sentiment': [{'ticker': 'CRYPTO:BTC', 'relevance_score': '0.116914', 'ticker_sentiment_score': '0.184356', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'CRYPTO:USDT', 'relevance_score': '0.116914', 'ticker_sentiment_score': '0.184356', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'CRYPTO:KCS', 'relevance_score': '0.622414', 'ticker_sentiment_score': '0.660107', 'ticker_sentiment_label': 'Bullish'}]}, {'title': 'How Global Markets Are Reacting To Iran-Israel Conflict - Invesco QQQ Trust, Series 1  ( NASDAQ:QQQ ) , SPDR S&P 500  ( ARCA:SPY ) ', 'url': 'https://www.benzinga.com/markets/asia/24/04/38241553/us-stock-futures-resilient-despite-weekend-iran-israel-escalation-asia-slips-gold-oil-holds-steady-b', 'time_published': '20240415T021856', 'authors': ['Shanthi Rexaline'], 'summary': "Much against fears that the weakness seen in recent sessions will intensify, early indications suggest that the U.S. market may stay resilient despite the tensions brewing in the Middle East following Iran's unprecedented attack on Israel.", 'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/Israel-And-Iran-Flags--Concrete-Wall-Tex.jpeg?width=1200&height=800&fit=crop', 'source': 'Benzinga', 'category_within_source': 'Trading', 'source_domain': 'www.benzinga.com', 'topics': [{'topic': 'Economy - Monetary', 'relevance_score': '0.310843'}, {'topic': 'Financial Markets', 'relevance_score': '0.77141'}, {'topic': 'Earnings', 'relevance_score': '0.451494'}, {'topic': 'Finance', 'relevance_score': '1.0'}], 'overall_sentiment_score': -0.077745, 'overall_sentiment_label': 'Neutral', 'ticker_sentiment': [{'ticker': 'GS', 'relevance_score': '0.152499', 'ticker_sentiment_score': '0.0', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'IVZ', 'relevance_score': '0.076602', 'ticker_sentiment_score': '0.311315', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'CRYPTO:BTC', 'relevance_score': '0.152499', 'ticker_sentiment_score': '-0.094714', 'ticker_sentiment_label': 'Neutral'}]}, {'title': 'Asia stocks slide, gold rises as Middle East conflict sparks safety rush', 'url': 'https://www.moneycontrol.com/news/business/markets/asia-stocks-slide-gold-rises-as-middle-east-conflict-sparks-safety-rush-12638751.html', 'time_published': '20240415T021423', 'authors': [], 'summary': 'The dollar scaled a fresh 34-year high against the yen on growing expectations that sticky inflationary pressures in the United States will keep rates there higher for longer.', 'banner_image': 'https://images.moneycontrol.com/static-mcnews/2017/08/sensex_NSE_BSE_Stocks_Stock_market_Asian_market1.jpg?impolicy=website&width=168&height=118', 'source': 'Money Control', 'categ ...

# %% [markdown]
# ### Os resultados da primeira notícia encontrada:

# %%
data['feed'][3]
# Out:
# {'title': "Bitcoin 'Will Resume Its Trend Higher,' Says Galaxy Digital CEO Amid Israel-Iran Escalation",
#  'url': 'https://www.benzinga.com/markets/cryptocurrency/24/04/38241323/bitcoin-will-resume-its-trend-higher-says-galaxy-digital-ceo-amid-israel-iran-escalation',
#  'time_published': '20240415T013937',
#  'authors': ['Benzinga Neuro'],
#  'summary': 'Mike Novogratz, CEO of Galaxy Digital, warned about the economic repercussions of war while forecasting a robust performance for Bitcoin BTC/USD. What Happened: Novogratz, the billionaire founder of Galaxy Digital, took to social media platform X on Sunday to express his concerns about the ...',
#  'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/04/14/Bitcoin-Vs-Gold-Vs-Stock-Market.jpeg?width=1200&height=800&fit=crop',
#  'source': 'Benzinga',
#  'category_within_source': 'News',
#  'source_domain': 'www.benzinga.com',
#  'topics': [{'topic': 'Economy - Monetary', 'relevance_score': '0.310843'},
#   {'topic': 'Blockchain', 'relevance_score': '0.158519'}],
#  'overall_sentiment_score': 0.125504,
#  'overall_sentiment_label': 'Neutral',
#  'ticker_sentiment': [{'ticker': 'BRPHF',
#    'relevance_score': '0.198221',
#    'ticker_sentiment_score': '-0.253674',
#    'ticker_sentiment_label': 'Somewhat-Bearish'},
#   {'ticker': 'CRYPTO:BTC',
#    'relevance_score': '0.7414',
#    'ticker_sentiment_score': '-0.071974',
#    'ticker_sentiment_label': 'Neutral'}]}

# %% [markdown]
# > ### 2. Efetuado a chamada, será preciso encontrar uma chave única por notícia para evitar duplicidades no pipeline e o mínimo de informações por notícia que será necessário armazenar é o título, data de publicação e o resultado da análise de sentimento para o Bitcoin, exemplo a seguir com todas essas informações necessárias da última nóticia:

# %%
print("Resultado para a primeira notícia encontrada:")
print("Título", data['feed'][0]['title'])
print("Data de publicação", data['feed'][0]['time_published'])
print("Resultado apenas do Ticker igual ao Bitcoin ('CRYPTO:BTC')", data['feed'][0]['ticker_sentiment'][1])
# Out:
# Resultado para a primeira notícia encontrada:
# Título KuCoin Announces a Monumental $20 Million Gratitude Airdrop for Its Loyal Community
# Data de publicação 20240415T021900
# Resultado apenas do Ticker igual ao Bitcoin ('CRYPTO:BTC') {'ticker': 'CRYPTO:USDT', 'relevance_score': '0.116914', 'ticker_sentiment_score': '0.184356', 'ticker_sentiment_label': 'Somewhat-Bullish'}

# %% [markdown]
# > ### 3. Preparar um pipeline capaz de extrair e armazenar essas informações em um banco de dados usando os conceitos das camadas especializadas Bronze e Silver

# %%
import pandas as pd

# Criar listas para armazenar os dados extraídos
titles = []
time_published = []
ticker_sentiments = []

for item in data['feed']:
    titles.append(item['title'])
    time_published.append(item['time_published'])
    ticker_sentiments.append(item['ticker_sentiment'])


df_bronze = pd.DataFrame({
    'title': titles,
    'time_published': time_published,
    'ticker_sentiment': ticker_sentiments
})

df_bronze
# Out:
#                                                  title   time_published  \
# 0    KuCoin Announces a Monumental $20 Million Grat...  20240415T021900
# 1    How Global Markets Are Reacting To Iran-Israel...  20240415T021856
# 2    Asia stocks slide, gold rises as Middle East c...  20240415T021423
# 3    Bitcoin 'Will Resume Its Trend Higher,' Says G...  20240415T013937
# 4    IRS investigation chief expects uptick in cryp...  20240415T003959
# ..                                                 ...              ...
# 136  Cathie Wood's Ark Invest Sells $20M+ Coinbase ...  20240412T025431
# 137  'We're High On' Bitcoin, Says Ultra Rich Inves...  20240412T021732
# 138  GBTC fees will drop when Bitcoin ETFs 'start t...  20240412T013140
# 139  El Salvador's newest Hilton hotel to tap into ...  20240412T005349
# 140  Sam Bankman-Fried, Founder Of FTX, Appeals Fra...  20240412T003415
#
#                                       ticker_sentiment
# 0    [{'ticker': 'CRYPTO:BTC', 'relevance_score': '...
# 1    [{'ticker': 'GS', 'relevance_score': '0.152499...
# 2    [{'ticker': 'CBAUF', 'relevance_score': '0.049...
# 3    [{'ticker': 'BRPHF', 'relevance_score': '0.198...
# 4    [{'ticker': 'CRYPTO:BTC', 'relevance_score': '...
# ..                                                 ...
# 136  [{'ticker': 'PATH', 'relevance_score': '0.2313...
# 137  [{'ticker': 'BRPHF', 'relevance_score': '0.110...
# 138  [{'ticker': 'CRYPTO:BTC', 'relevance_score': '...
# 139  [{'ticker': 'CYFRF', 'relevance_score': '0.091...
# 140  [{'ticker': 'CRCW', 'relevance_score': '0.1141...
#
# [141 rows x 3 columns]

# %%
df_bronze.dtypes
# Out:
# title               object
# time_published      object
# ticker_sentiment    object
# dtype: object

# %%
# !pip install sqlalchemy psycopg2-binary
# !pip install psycopg2-binary

# %%
# Serializar os dados da coluna "ticker_sentiment" para ser armazenada no banco de dados como JSON.
import json

df_bronze['ticker_sentiment'] = df_bronze['ticker_sentiment'].apply(json.dumps)

# %%
from sqlalchemy import create_engine
import pandas as pd


conn_str = 'postgresql://username:password@hostname:port/database'

engine = create_engine(conn_str)

df_bronze.to_sql('sentimento_btc', con=engine, if_exists='replace', index=False)
# Out:
# 141

# %% [markdown]
# ## Camada Silver

# %%
from sqlalchemy import create_engine, text as sql_text

query = """
SELECT *
FROM public.sentimento_btc
"""
df_silver = pd.read_sql(sql=sql_text(query), con=engine.connect())
df_silver
# Out:
#                                                  title   time_published  \
# 0    KuCoin Announces a Monumental $20 Million Grat...  20240415T021900
# 1    How Global Markets Are Reacting To Iran-Israel...  20240415T021856
# 2    Asia stocks slide, gold rises as Middle East c...  20240415T021423
# 3    Bitcoin 'Will Resume Its Trend Higher,' Says G...  20240415T013937
# 4    IRS investigation chief expects uptick in cryp...  20240415T003959
# ..                                                 ...              ...
# 136  Cathie Wood's Ark Invest Sells $20M+ Coinbase ...  20240412T025431
# 137  'We're High On' Bitcoin, Says Ultra Rich Inves...  20240412T021732
# 138  GBTC fees will drop when Bitcoin ETFs 'start t...  20240412T013140
# 139  El Salvador's newest Hilton hotel to tap into ...  20240412T005349
# 140  Sam Bankman-Fried, Founder Of FTX, Appeals Fra...  20240412T003415
#
#                                       ticker_sentiment
# 0    [{"ticker": "CRYPTO:BTC", "relevance_score": "...
# 1    [{"ticker": "GS", "relevance_score": "0.152499...
# 2    [{"ticker": "CBAUF", "relevance_score": "0.049...
# 3    [{"ticker": "BRPHF", "relevance_score": "0.198...
# 4    [{"ticker": "CRYPTO:BTC", "relevance_score": "...
# ..                                                 ...
# 136  [{"ticker": "PATH", "relevance_score": "0.2313...
# 137  [{"ticker": "BRPHF", "relevance_score": "0.110...
# 138  [{"ticker": "CRYPTO:BTC", "relevance_score": "...
# 139  [{"ticker": "CYFRF", "relevance_score": "0.091...
# 140  [{"ticker": "CRCW", "relevance_score": "0.1141...
#
# [141 rows x 3 columns]

# %%
df_silver.dtypes
# Out:
# title               object
# time_published      object
# ticker_sentiment    object
# dtype: object

# %%
import pandas as pd
import json

# Converte a coluna "time_published" para datetime e extrai o dia da publicação para uma coluna "day_published"
df_silver['time_published'] = pd.to_datetime(df_silver['time_published'])
df_silver['day_published'] = df_silver['time_published'].dt.date

# Converter a coluna 'day_published' para o formato de data ideal
df_silver['day_published'] = pd.to_datetime(df_silver['day_published'], format='%Y%m%d')

# Extrair os sentimentos de cada notícia
df_silver['sentiments'] = df_silver['ticker_sentiment'].apply(lambda x: [float(item['ticker_sentiment_score']) for item in json.loads(x)])

df_silver['mean_sentiment'] = df_silver['sentiments'].apply(lambda x: round(sum(x) / len(x), 2) if len(x) > 0 else 0)

# %%
df_silver.to_sql('tabela_silver', con=engine, if_exists='replace', index=False)
# Out:
# 141

# %% [markdown]
# > ### 4. Por fim, desenvolver um pipeline de dados transformados para contabilizar a quantidade de notícias encontradas por dia, e o "sentimento médio" por dia na camada Gold

# %%
from sqlalchemy import create_engine, text as sql_text

query = """
SELECT *
FROM public.tabela_silver
"""
df_gold = pd.read_sql(sql=sql_text(query), con=engine.connect())
df_gold
# Out:
#                                                  title      time_published  \
# 0    KuCoin Announces a Monumental $20 Million Grat... 2024-04-15 02:19:00
# 1    How Global Markets Are Reacting To Iran-Israel... 2024-04-15 02:18:56
# 2    Asia stocks slide, gold rises as Middle East c... 2024-04-15 02:14:23
# 3    Bitcoin 'Will Resume Its Trend Higher,' Says G... 2024-04-15 01:39:37
# 4    IRS investigation chief expects uptick in cryp... 2024-04-15 00:39:59
# ..                                                 ...                 ...
# 136  Bitcoin no longer in 'easy mode' - expect a le... 2024-04-12 04:03:00
# 137  Technical charts suggest a roaring altseason m... 2024-04-12 03:38:05
# 138  Cathie Wood's Ark Invest Sells $20M+ Coinbase ... 2024-04-12 02:54:31
# 139  'We're High On' Bitcoin, Says Ultra Rich Inves... 2024-04-12 02:17:32
# 140  Sam Bankman-Fried, Founder Of FTX, Appeals Fra... 2024-04-12 00:34:15
#
#                                       ticker_sentiment day_published  \
# 0    [{"ticker": "CRYPTO:BTC", "relevance_score": "...    2024-04-15
# 1    [{"ticker": "GS", "relevance_score": "0.152499...    2024-04-15
# 2    [{"ticker": "CBAUF", "relevance_score": "0.049...    2024-04-15
# 3    [{"ticker": "BRPHF", "relevance_score": "0.198...    2024-04-15
# 4    [{"ticker": "CRYPTO:BTC", "relevance_score": "...    2024-04-15
# ..                                                 ...           ...
# 136  [{"ticker": "CRYPTO:BTC", "relevance_score": "...    2024-04-12
# 137  [{"ticker": "CRYPTO:BTC", "relevance_score": "...    2024-04-12
# 138  [{"ticker": "PATH", "relevance_score": "0.2313...    2024-04-12
# 139  [{"ticker": "BRPHF", "relevance_score": "0.110...    2024-04-12
# 140  [{"ticker": "CRCW", "relevance_score": "0.1141...    2024-04-12
#
#                                             sentiments  mean_sentiment
# 0                         {0.184356,0.184356,0.660107}            0.34
# 1                             {0.0,0.311315,-0.094714}            0.07
# 2    {0.038877,-0.008878,-0.166198,-0.166198,-0.008...           -0.06
# 3                                {-0.253674,-0.071974}           -0.16
# 4                                           {0.120285}            0.12
# ..                                                 ...             ...
# 136                                         {0.136076}            0.14
# 137  {0.296913,-0.076694,-0.076694,-0.076694,-0.076...           -0.01
# 138  {0.447904,0.292292,0.447904,0.461358,0.181413,...            0.40
# 139                                {0.213117,0.726247}            0.47
# 140                      {-0.454795,0.113878,0.113878}           -0.08
#
# [141 rows x 6 columns]

# %%
# Calcula a quantidade de notícias por dia
df_gold = df_gold.groupby('day_published').agg(
    num_news=('title', 'count'),
    mean_sentiment=('mean_sentiment', 'mean')
).reset_index()

print(df_gold)
# Out:
#   day_published  num_news  mean_sentiment
# 0    2024-04-12        92        0.185217
# 1    2024-04-13        20        0.081000
# 2    2024-04-14        24        0.034167
# 3    2024-04-15         5        0.062000

# %%
df_gold.to_sql('tabela_gold', con=engine, if_exists='replace', index=False)
# Out:
# 4

# %% [markdown]
# ## Resultado

# %%
from sqlalchemy import create_engine, text as sql_text

query = """
SELECT *
FROM public.tabela_gold
"""
final = pd.read_sql(sql=sql_text(query), con=engine.connect())
final
# Out:
#   day_published  num_news  mean_sentiment
# 0    2024-04-12        92        0.185217
# 1    2024-04-13        20        0.081000
# 2    2024-04-14        24        0.034167
# 3    2024-04-15         5        0.062000
